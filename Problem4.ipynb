# %%
from problem4_capacity_optimization import Problem4CapacityOptimizer

optimizer = Problem4CapacityOptimizer()
optimal_capacity = optimizer.run_optimization()
# Out:
# ============================================================
# 问题四：产能提升潜力分析与最优方案
# ============================================================
# 加载基础数据...
# 检查预测模型...
# ✓ 时间序列预测模型初始化完成
# ✓ 时间序列模型已从文件加载: models/timeseries_supplier_model.pkl
# ✓ 预测模型可用
# ✓ 加载完成：402 家供应商，8 家转运商
#   A类: 146家供应商, 平均产能: 10,091, 最大产能: 169,618, Top50: 14家
#   B类: 134家供应商, 平均产能: 9,461, 最大产能: 101,182, Top50: 16家
#   C类: 122家供应商, 平均产能: 8,381, 最大产能: 113,112, Top50: 20家
#
# 基于预测模型分析产能提升潜力...
#   分析A类材料供应商(146家)...
#     A类材料可支持最大产能: 97,326 立方米/周 (预测模型+历史数据加权(146/146家供应商))
#   分析B类材料供应商(134家)...
#     B类材料可支持最大产能: 57,355 立方米/周 (预测模型+历史数据加权(134/134家供应商))
#   分析C类材料供应商(122家)...
#     C类材料可支持最大产能: 57,074 立方米/周 (预测模型+历史数据加权(122/122家供应商))
#
# 供应商能力限制的最大产能: 57,074 立方米/周
# 转运商能力限制分析:
#   - 8家转运商×6000立方米/周 = 48,000 立方米/周
#   - 考虑1.5%损耗后有效运力: 47,280 立方米/周
#   - 转换为产品制造能力: 71,183 立方米/周
#   - 加权平均原材料消耗率: 0.664
#
# === 产能提升分析结果 ===
# 分析方法说明: 基于时间序列预测模型的可持续供应能力
# 当前产能: 28,200 立方米/周
# 最大可达产能: 57,074 立方米/周
# 可提升产能: 28,874 立方米/周
# 提升幅度: 102.4%
# ✓ 有产能提升空间
#
# 生成基于57,074立方米/周产能的供货计划...
# 每周最大转运能力: 48,000 立方米
# 目标产能(57,074立方米/周)所需原材料: 37,908 立方米/周
# 加权平均原材料消耗率: 0.664
# ✓ 转运能力充足，维持目标产能: 57,074 立方米/周
#   A类原材料需求: 34,244 立方米/周
#   B类原材料需求: 37,669 立方米/周
#   C类原材料需求: 41,093 立方米/周
#   总原材料需求: 113,006 立方米/周
# ⚠ 警告：总原材料需求(113,006)超过转运能力(48,000)
# 按比例调整系数: 0.425
#   调整后A类需求: 14,545 立方米/周
#   调整后B类需求: 16,000 立方米/周
#   调整后C类需求: 17,455 立方米/周
#   获取供应商预测供货能力...
#     ✓ 获取402家供应商的预测供货能力
#     第1周A类: 使用13家供应商(预测模型指导: 13家), 分配14,545立方米
#     第1周B类: 使用6家供应商(预测模型指导: 6家), 分配16,000立方米
#     第1周C类: 使用19家供应商(预测模型指导: 19家), 分配17,455立方米
#     第1周总供货量: 48,000 立方米
# ✓ 供货计划生成完成，共912条记录，平均每周38.0条
# ✓ 其中912条记录基于预测模型指导
#
# 分配转运商...
# ✓ 转运方案生成完成，共1080条记录
#
# 转运方案分析:
#   总供货量: 1,152,000 立方米
#   总损耗量: 15,992 立方米
#   总接收量: 1,136,008 立方米
#   平均损耗率: 1.39%
#
# 转运商使用情况:
#   T1: 运输量 144,000, 使用次数 120, 损耗率 1.90%
#   T2: 运输量 144,000, 使用次数 48, 损耗率 0.92%
#   T3: 运输量 144,000, 使用次数 24, 损耗率 0.19%
#   T4: 运输量 144,000, 使用次数 72, 损耗率 1.57%
#   T5: 运输量 144,000, 使用次数 576, 损耗率 2.89%
#   T6: 运输量 144,000, 使用次数 48, 损耗率 0.54%
#   T7: 运输量 144,000, 使用次数 144, 损耗率 2.08%
#   T8: 运输量 144,000, 使用次数 48, 损耗率 1.01%
#
# 导出结果...
# ✓ 结果已导出到DataFrames/问题4_订购方案.xlsx
# ✓ 结果已导出到DataFrames/问题4_转运方案.xlsx
# ✓ 详细报告已导出到DataFrames/问题4_详细分析报告.xlsx
#
# ============================================================
# 问题四优化完成
# ============================================================
